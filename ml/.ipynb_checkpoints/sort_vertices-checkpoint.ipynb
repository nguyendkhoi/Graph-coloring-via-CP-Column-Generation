# %% [markdown]
# Libraries

# %%
import pandas as pd
import torch
from torch import nn
# Out:
# Failed to start the Kernel.
#
# [IPKernelApp] WARNING | Kernel is running over TCP without encryption. All communication (including code and outputs) is sent in plain text and is susceptible to eavesdropping. Use IPC transport or launch with kernel manager-provisioned CurveZMQ keys to enable transport encryption.
#
# Bad file descriptor (D:\bld\bld\rattler-build_zeromq_1779124031\work\src\epoll.cpp:73).
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# Take a data from folder master_cp/runs of vertices

# %%
df = pd.read_csv("../master_cp/runs/DSJC125.9/0596aeaa-b95b-489f-aaaa-4505b03178d8/vertex_features.csv")

print(vertices_df.head())
# Out:
# Failed to start the Kernel.
#
# [IPKernelApp] WARNING | Kernel is running over TCP without encryption. All communication (including code and outputs) is sent in plain text and is susceptible to eavesdropping. Use IPC transport or launch with kernel manager-provisioned CurveZMQ keys to enable transport encryption.
#
# Bad file descriptor (D:\bld\bld\rattler-build_zeromq_1779124031\work\src\epoll.cpp:73).
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
